# %%
import numpy as np

# %%
# Question 2

company_matrix = np.array([
    [2350,2000,2000,2150],
    [500,405,350,210],
    [200,250,400,450]
])


# Part b

exchange_matrix = np.array([1,2,3])

b_result = exchange_matrix @ company_matrix

print(b_result)

# Part c

summation_matrix = np.array([1,1,1,1])

c_result = company_matrix @ summation_matrix
print(c_result)

# Part d

d_result = (exchange_matrix @ company_matrix) @ summation_matrix
print(d_result)
# Out:
# [3950 3560 3900 3920]
# [8500 1465 1300]
# 15330

# %%
# Question 3

matrix_A = np.array([
    [8,0,1,1],
    [9,2,9,4],
    [1,5,9,9],
    [9,9,4,7],
    [6,9,8,9]
])

# Part A

y_a = np.array([0,0,1,0,0])

a_result = y_a @ matrix_A
print(a_result)

# Part B

k_b = 1 # must be 0,1,2,3,4 for indexing
y_b = np.array([0,0,0,0,0])
y_b[k_b] = 1

b_result = y_b @ matrix_A
print(b_result)

# Part C

y_c = np.array([3,0,-2,0,0])

c_result = y_c @ matrix_A
print(c_result)

# Part D

y_d = np.array([-1,0,1,0])

d_result = matrix_A @ y_d
print(d_result)

# Part E

k_e = 1 # k  must be 0,1,2,3 for indexing
y_e = np.array([0,0,0,0])
y_e[k_e] = 1

e_result = matrix_A @ y_e
print(e_result)

# Part F

k_f = 1 # k and j must bf 0,1,2,3 for indexing and k != j
j_f = 0
a = 3 # Some constant
b = 4 # Some constant
y_f = np.array([0,0,0,0])
y_f[k_f] = a
y_f[j_f] = b

f_result = matrix_A @ y_f
print(f_result)
# Out:
# [1 5 9 9]
# [9 2 9 4]
# [ 22 -10 -15 -15]
# [-7  0  8 -5  2]
# [0 2 5 9 9]
# [32 42 19 63 51]

# %%
# Question 6

import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt

# n = number of points
# z = points where polynomial is evaluated
# p = array to store the values of the interpolated polynomials

n = 100
z = np.linspace(-1,1,n)

d = 3 # degree
w = np.random.rand(d)
X = np.zeros((n,d))

# TODO : generate X - matrix
for i in range(n):
  for j in range(d):
    X[i][j] = z[i]**(j+1)


# TODO : evaluate polynomial at all points z,
# and store the result in p
# do NOT use a loop for this

p = X @ w

# plot the datapoints and the best - fit polynomials
plt.plot(z,p,linewidth=2)
plt.xlabel('z')
plt.ylabel('y')
plt.title('polynomial with coefficients w = % s' %w)
plt.show()
